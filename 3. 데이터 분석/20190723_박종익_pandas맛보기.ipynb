# %% [markdown]
# 판다스는 직사각형 - 표 형태의 구조!
#
# 관계형 데이터베이스를 이 형태로 관리한다... 효율적으로 사용가능하기 때문에!!
#
# 데이터 분석은 이런 이차원의 테이블 형태로 하면 가장 효율적이라고 알려져 있다...
#
# 모든 데이터 형태는 이차원 직사각형으로 이루어져 있다.
#
# 분석 알고리즘을 사용하는 툴들 또한 이차원 직사각형 테이블 기반이다.
#
# 전체를 DataFrame
#
# 맨 위에 있는 것들 Column 또는 header
#
# 맨 왼쪽에 있는 아이들 index

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
type(tips)
##판다스의 기본적인 자료형태 ... DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
tips.head() ##structured array를 이용하여 만들었을 것!
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['day'].head()
##structured array로 만들었기 때문에! 키 방식으로 접근 가능
# Out:
# 0    Sun
# 1    Sun
# 2    Sun
# 3    Sun
# 4    Sun
# Name: day, dtype: category
# Categories (4, object): [Thur, Fri, Sat, Sun]

# %%
tips.smoker.head()
## attribute방식 또한 접근이 가능하다!!! 판다스는 가능~
## 공백이나 size와 같이 미리 정의된 아이들은 안된다...
## 단점이 있지만 왜?? 편하니까!
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: smoker, dtype: category
# Categories (2, object): [Yes, No]

# %%
tips.size
# Out:
# 1708

# %%
tips["size"].head()
# Out:
# 0    2
# 1    3
# 2    3
# 3    2
# 4    4
# Name: size, dtype: int64

# %%
tips.loc[0] 
## row를 가져오려면 loc or iloc을 사용하면 된다!
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
tips.iloc[0]
##이건 인덱싱
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
tips[:5] ##슬라이싱을 통해 가능!
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(tips[["day","time"]])
##Fancy indexing방식이 가능함!!
# Out:
# pandas.core.frame.DataFrame

# %%
type(tips.day)
# Out:
# pandas.core.series.Series

# %%
tips.tip.values
##array!! numpy형태의 데이터!
# Out:
# array([  1.01,   1.66,   3.5 ,   3.31,   3.61,   4.71,   2.  ,   3.12,
#          1.96,   3.23,   1.71,   5.  ,   1.57,   3.  ,   3.02,   3.92,
#          1.67,   3.71,   3.5 ,   3.35,   4.08,   2.75,   2.23,   7.58,
#          3.18,   2.34,   2.  ,   2.  ,   4.3 ,   3.  ,   1.45,   2.5 ,
#          3.  ,   2.45,   3.27,   3.6 ,   2.  ,   3.07,   2.31,   5.  ,
#          2.24,   2.54,   3.06,   1.32,   5.6 ,   3.  ,   5.  ,   6.  ,
#          2.05,   3.  ,   2.5 ,   2.6 ,   5.2 ,   1.56,   4.34,   3.51,
#          3.  ,   1.5 ,   1.76,   6.73,   3.21,   2.  ,   1.98,   3.76,
#          2.64,   3.15,   2.47,   1.  ,   2.01,   2.09,   1.97,   3.  ,
#          3.14,   5.  ,   2.2 ,   1.25,   3.08,   4.  ,   3.  ,   2.71,
#          3.  ,   3.4 ,   1.83,   5.  ,   2.03,   5.17,   2.  ,   4.  ,
#          5.85,   3.  ,   3.  ,   3.5 ,   1.  ,   4.3 ,   3.25,   4.73,
#          4.  ,   1.5 ,   3.  ,   1.5 ,   2.5 ,   3.  ,   2.5 ,   3.48,
# ...

# %%
tips.tip.head() + 5
##Broadcasting 기법또한 된다~~ Numpy기반!
# Out:
# 0    6.01
# 1    6.66
# 2    8.50
# 3    8.31
# 4    8.61
# Name: tip, dtype: float64

# %%
tips.tip.sum()
# Out:
# 731.57999999999993

# %%
tips.iloc[3]
##index location
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.iloc[3:6]
##iloc는 끝에있는 부분 포함 X
##파이썬 기법!
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
tips.loc[3]
# Out:
# total_bill     23.68
# tip             3.31
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 3, dtype: object

# %%
tips.loc[3:6]
##loc의 경우 6이 포함!!
##쪼큼 다름... 아마 R!
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2

# %%
tips.loc[3:6,["day","smoker"]]
# Out:
#    day smoker
# 3  Sun     No
# 4  Sun     No
# 5  Sun     No
# 6  Sun     No

# %%
tips.loc[3:6,["size","day"]]
# Out:
#    size  day
# 3     2  Sun
# 4     4  Sun
# 5     4  Sun
# 6     2  Sun

# %%
tips.iloc[3:6,:-2]
##얘는 파이썬과 똑같기에 column 또한 숫자로 접근 가능!!
# Out:
#    size    time  day smoker     sex   tip  total_bill
# 3     2  Dinner  Sun     No    Male  3.31       23.68
# 4     4  Dinner  Sun     No  Female  3.61       24.59
# 5     4  Dinner  Sun     No    Male  4.71       25.29

# %%
tips.iloc[3:6,::-1] ##역수로 출력
## but!! ...은 지원 X
# Out:
#    size    time  day smoker     sex   tip  total_bill
# 3     2  Dinner  Sun     No    Male  3.31       23.68
# 4     4  Dinner  Sun     No  Female  3.61       24.59
# 5     4  Dinner  Sun     No    Male  4.71       25.29

# %% [markdown]
# - Column 가져오는 최소 5가지 방식
#     1. attribute
#     2. key방식 ... 가장빠르다~~
#     3. Fancy Indexing ... 가장 느림... 그리고 columns도 사용가능~
#     4. filter ... 정규식을 사용하기 때문에
#     5. select_dtypes
#
# 적절한 상황에 맞춰서 열을 가져올 것!!

# %%
tips[['tip']].head()
##이 친구는 Series가 아닌 DF으로 가져온다~
# Out:
#     tip
# 0  1.01
# 1  1.66
# 2  3.50
# 3  3.31
# 4  3.61

# %% [markdown]
# - Row 가져오는 방식
#     1. loc - 이름 ... 이름끝까지 포함! ... 더 느림...
#     2. iloc - index ... 이름 마지막 꺼 포함 X ...더 빠름!

# %%
# %timeit tips.iloc[3:6]
# Out:
# 217 µs ± 905 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit tips.loc[3:5]
# Out:
# 230 µs ± 1.79 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit tips.iat[3,5] ##i 쓰는 아이가 가장 빠르다!!
##But! 상황에 따라서 쓰는 방식이 다르다...
# Out:
# 7.18 µs ± 64.8 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit tips.at[3,'time']
# Out:
# 12.7 µs ± 132 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit tips.loc[3,'time']
# Out:
# 15.4 µs ± 43.5 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# 판다스는 EDA와 Preprocessing 하는 툴이다~
#
# - Pandas는 **Data Munging or wrangling** 툴이다!
#
# 데이터 불러오고, 기초분석하고 등등...
#
# wrangling은 분석가 관점! ETA는 개발자 관점
#
# EDA : Exploratory Data Analysis 탐색적 데이터 분석

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# 성별, 흡연유무, 요일, 시간, 덩치에 따라서 팁의 유무
#
# 데이터에서 끄집어 낼 수 있는 것들!
#
# 남/여 별로 팁이 얼마나? 흡연자들이 팁을 많이 내나??
#
# 어떤 요일 어떤 시간대에 팁이 가장 많을까??

# %%
tips.info()
##여기서 category가 딱 뜬다
##보통은 object 이지만, 몇개 없을 때 category
##오캄의 면도칼, 차원의 저주
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips.describe()
### size는 덩치!! 그래서 category로 되어야 한다!
## 평균이 20달러, 팁이 3달러 비싼 식당은 아니다!
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe(include="category")
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
tips.boxplot()

# %%
tips[["total_bill","tip"]].boxplot()
##두 컬럼만 가져오는 것 -> Fancy Indexing

# %%
##aggregation
tips.groupby("sex").mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
tips.groupby("smoker").mean() ##sum min max 등등
# Out:
#         total_bill       tip      size
# smoker
# Yes      20.756344  3.008710  2.408602
# No       19.188278  2.991854  2.668874

# %%
tips.groupby("day").mean()
# Out:
#       total_bill       tip      size
# day
# Thur   17.682742  2.771452  2.451613
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105

# %%
tips.groupby("time").mean()
# Out:
#         total_bill       tip      size
# time
# Lunch    17.168676  2.728088  2.411765
# Dinner   20.797159  3.102670  2.630682

# %%
##동시에 두개 이상
tips.groupby(["sex","day"]).mean()
# Out:
#              total_bill       tip      size
# sex    day
# Male   Thur   18.714667  2.980333  2.433333
#        Fri    19.857000  2.693000  2.100000
#        Sat    20.802542  3.083898  2.644068
#        Sun    21.887241  3.220345  2.810345
# Female Thur   16.715312  2.575625  2.468750
#        Fri    14.145556  2.781111  2.111111
#        Sat    19.680357  2.801786  2.250000
#        Sun    19.872222  3.367222  2.944444

# %%
tips.groupby(["sex","day","time"])["total_bill","tip"].mean()
# Out:
#                     total_bill       tip
# sex    day  time
# Male   Thur Lunch    18.714667  2.980333
#             Dinner         NaN       NaN
#        Fri  Lunch    11.386667  1.900000
#             Dinner   23.487143  3.032857
#        Sat  Lunch          NaN       NaN
#             Dinner   20.802542  3.083898
#        Sun  Lunch          NaN       NaN
#             Dinner   21.887241  3.220345
# Female Thur Lunch    16.648710  2.561935
#             Dinner   18.780000  3.000000
#        Fri  Lunch    13.940000  2.745000
#             Dinner   14.310000  2.810000
#        Sat  Lunch          NaN       NaN
#             Dinner   19.680357  2.801786
#        Sun  Lunch          NaN       NaN
#             Dinner   19.872222  3.367222

# %% [markdown]
# 일요일 저녁에 식사하러오는 남자들이 대체로 팁을 많이 준다... 사기! 개별적인 상황을 확대해석!!
#
# But, 경향을 보여주는 데에는 괜찮다~

# %%
t = tips.groupby(["sex"])["total_bill","tip"].mean()

# %%
t.plot.bar()

# %%
t.plot.barh()

# %%
sns.pairplot(tips[["total_bill","tip"]])

# %% [markdown]
# 다시 tips로!

# %%
tips.rename(columns = {"size" : "size_"})
tips.rename({"size" : "size_"}, axis=1, inplace=True)

# %%
tips["size_"] = tips["size_"].astype('category')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size_         244 non-null category
# dtypes: category(5), float64(2)
# memory usage: 5.8 KB

# %%
tips.sex.value_counts()
##맨 왼쪽에 있는 아이의 이름은 index
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.sex.value_counts().loc["Male"]
# Out:
# 157

# %%
tips.sex.value_counts().iloc[0]
# Out:
# 157

# %% [markdown]
# 판다스 그래프는 쉽다!!
#
# 왜냐하면 인덱스는 무조건 x축이다

# %%
tips.sex.value_counts().plot.bar()

# %%
tips.sex.value_counts().plot('pie')

# %%
tips.size_.value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size_, dtype: int64

# %%
tips.sex.unique()
##이 두개 외에 다른 데이터를 집어넣으려고 하면 에러!!
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
tips.sex.nunique()
##카테고리 개수가 나옴!
# Out:
# 2

# %%
t = tips.sex.cat ##자동완성 보여주기용
#t.add_categories() ##추가기능이 나온다~

# %%
t.codes
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 11     1
# 12     0
# 13     0
# 14     1
# 15     0
# 16     1
# 17     0
# 18     1
# 19     0
# 20     0
# 21     1
# 22     1
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     0
# 29     1
#       ..
# 214    1
# 215    1
# 216    0
# 217    0
# 218    0
# 219    1
# 220    0
# 221    1
# 222    0
# 223    1
# 224    0
# 225    1
# 226    1
# 227    0
# 228    0
# 229    1
# 230    0
# 231    0
# 232    0
# 233    0
# 234    0
# 235    0
# 236    0
# 237    0
# 238    1
# 239    0
# 240    1
# 241    0
# 242    0
# 243    1
# Length: 244, dtype: int8

# %%
t = tips.size_.cat

# %%
t.codes
## 이건 라벨인코딩
## one-hot 인코딩은 컬럼이 여러개 있어야 한다~
## datetime객체는 .dt를 통해서도 가능하다
# Out:
# 0      1
# 1      2
# 2      2
# 3      1
# 4      3
# 5      3
# 6      1
# 7      3
# 8      1
# 9      1
# 10     1
# 11     3
# 12     1
# 13     3
# 14     1
# 15     1
# 16     2
# 17     2
# 18     2
# 19     2
# 20     1
# 21     1
# 22     1
# 23     3
# 24     1
# 25     3
# 26     1
# 27     1
# 28     1
# 29     1
#       ..
# 214    2
# 215    1
# 216    4
# 217    1
# 218    1
# 219    3
# 220    1
# 221    1
# 222    0
# 223    2
# 224    1
# 225    1
# 226    1
# 227    3
# 228    1
# 229    1
# 230    3
# 231    2
# 232    1
# 233    1
# 234    1
# 235    1
# 236    1
# 237    1
# 238    2
# 239    2
# 240    1
# 241    1
# 242    1
# 243    1
# Length: 244, dtype: int8

# %%
tips.head()
##size 타입이 바뀌는 거는 도메인 지식으로!
# Out:
#    total_bill   tip     sex smoker  day    time size_
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["size_"].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size_, dtype: int64

# %%
tips.groupby(["size_","sex"]).mean()
# Out:
#               total_bill       tip
# size_ sex
# 1     Male      8.580000  1.920000
#       Female    6.796667  1.276667
# 2     Male     17.104082  2.614184
#       Female   15.339483  2.528448
# 3     Male     24.287083  3.476667
#       Female   21.547143  3.250000
# 4     Male     28.078214  4.172143
#       Female   30.278889  4.021111
# 5     Male     30.122500  3.750000
#       Female   29.850000  5.140000
# 6     Male     41.235000  5.850000
#       Female   28.425000  4.600000

# %% [markdown]
# 사실 size는 사람들의 수이다!!
#
# 왜냐하면 size가 증가할수록 total이 확확 증가하기 때문에~

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
mpg.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 364  26.6          8         350.0       105.0    3725          19.0
# 359  28.1          4         141.0        80.0    3230          20.4
# 226  20.5          6         231.0       105.0    3425          16.9
# 351  34.4          4          98.0        65.0    2045          16.2
# 52   30.0          4          88.0        76.0    2065          14.5
#
#      model_year  origin                       name
# 364          81     usa      oldsmobile cutlass ls
# 359          81  europe  peugeot 505s turbo diesel
# 226          77     usa              buick skylark
# 351          81     usa             ford escort 4w
# 52           71  europe                  fiat 124b

# %%
mpg.info()
##horsepower가 392개 ... missingdata가 6개
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null object
# name            398 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg.head(10).describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count  10.000000       10.0     10.000000   10.000000    10.000000
# mean   15.600000        8.0    374.900000  178.300000  3879.700000
# std     1.577621        0.0     65.722396   35.543557   432.151735
# min    14.000000        8.0    302.000000  130.000000  3433.000000
# 25%    14.250000        8.0    309.750000  150.000000  3462.750000
# 50%    15.000000        8.0    370.000000  177.500000  3771.500000
# 75%    16.750000        8.0    437.250000  210.750000  4333.750000
# max    18.000000        8.0    455.000000  225.000000  4425.000000
#
#        acceleration  model_year
# count     10.000000        10.0
# mean      10.300000        70.0
# std        1.337494         0.0
# min        8.500000        70.0
# 25%        9.250000        70.0
# 50%       10.250000        70.0
# 75%       11.375000        70.0
# max       12.000000        70.0

# %%
mpg.tail(10).describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count  10.000000  10.000000     10.000000   10.000000    10.000000
# mean   30.500000   4.200000    142.900000   85.700000  2596.500000
# std     6.150881   0.632456     35.766061   15.114746   258.199428
# min    22.000000   4.000000     97.000000   52.000000  2130.000000
# 25%    27.000000   4.000000    123.750000   82.500000  2423.750000
# 50%    29.500000   4.000000    137.500000   85.000000  2645.000000
# 75%    32.000000   4.000000    149.250000   91.500000  2772.500000
# max    44.000000   6.000000    232.000000  112.000000  2950.000000
#
#        acceleration  model_year
# count     10.000000        10.0
# mean      16.320000        82.0
# std        3.797894         0.0
# min       11.600000        82.0
# 25%       14.050000        82.0
# 50%       15.150000        82.0
# 75%       18.275000        82.0
# max       24.600000        82.0

# %% [markdown]
# 최근 수집된 데이터와 나중에 수집된 데이터간의 차이가 있을 수 있다.
#
# 그래서 관측된 데이터간의 차이가 있는지 없는지를 체크 해줘야한다!!

# %%
import missingno as mino

# %%
dir(mino)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'bar',
#  'dendrogram',
#  'geoplot',
#  'heatmap',
#  'matrix',
#  'missingno',
#  'nullity_filter',
#  'nullity_sort',
#  'utils']

# %%
mino.matrix(mpg)

# %%
mino.dendrogram(mpg)
##클러스터링

# %%
mino.heatmap(mpg)

# %%
sns.heatmap(mpg.dropna().corr())

# %%
sns.heatmap(mpg.corr())

# %%
mpg.horsepower.isna()
##predicate
## TF만 나오면 마스킹 기법을 사용할 수 있다!!
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 368    False
# 369    False
# 370    False
# 371    False
# 372    False
# 373    False
# 374     True
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: horsepower, Length: 398, dtype: bool

# %%
sum(mpg.horsepower.isna())
# Out:
# 6

# %% [markdown]
# Missing Data 처리
# 1. 버리라
# 2. interpolate ... 도메인 지식 필요!

# %%
mpg[mpg.horsepower.isna()] 
## Masking 기법
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
import pandas as pd

# %%
pd.isna is pd.isnull
##같다~~ 그래서 isna 써라~
## missing data 만드는 것 또한 가짜데이터를 만들어 내는 것!!
# Out:
# True

# %%
from scipy import interpolate ##도메인 지식이 필요!

# %%
mpg_raw = mpg.copy()

# %%
mpg[mpg.horsepower.isna()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
mpg.fillna(3,inplace=True)

# %%
#mpg.dropna(inplace=True)
##싹 다 날려~

# %%
mpg.drop("weight",axis=1).describe().T.plot.bar()

# %%
mpg.filter(regex='[^=weight]',axis=1).head()
##정규식으로 쟤가 들어간 애들 빼고 가져오겠다~
# Out:
#     mpg  cylinders  displacement  horsepower  acceleration  model_year origin  \
# 0  18.0          8         307.0       130.0          12.0          70    usa
# 1  15.0          8         350.0       165.0          11.5          70    usa
# 2  18.0          8         318.0       150.0          11.0          70    usa
# 3  16.0          8         304.0       150.0          12.0          70    usa
# 4  17.0          8         302.0       140.0          10.5          70    usa
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
mpg.filter(regex='[^=weight]',axis=1)
##이거 말고 하나 더 찾아내기

# %%
mpg.select_dtypes("object").head()
# Out:
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
mpg[mpg.columns[:-2]].head() ## 이것 또한 Fancy 방식
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0       130.0    3504          12.0          70
# 1  15.0          8         350.0       165.0    3693          11.5          70
# 2  18.0          8         318.0       150.0    3436          11.0          70
# 3  16.0          8         304.0       150.0    3433          12.0          70
# 4  17.0          8         302.0       140.0    3449          10.5          70

# %%
mpg.filter(regex='[^=weight]',axis=1).describe().T.plot.bar(stacked=True);
## cumulative bar plot

# %% [markdown]
# - Column 가져오는 최소 5가지 방식
#     1. attribute
#     2. key방식 ... 가장빠르다~~
#     3. Fancy Indexing ... 가장 느림... 그리고 columns도 사용가능~
#     4. filter ... 정규식을 사용하기 때문에
#     5. select_dtypes

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      398 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null object
# name            398 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
sns.pairplot(mpg)
##계단식 그래프는 category 데이터~

# %%
mpg.cov()
##공분산
# Out:
#                       mpg    cylinders  displacement    horsepower  \
# mpg             61.089611   -10.308911   -655.402318   -237.202142
# cylinders      -10.308911     2.893415    168.623214     56.231523
# displacement  -655.402318   168.623214  10872.199152   3658.213403
# horsepower    -237.202142    56.231523   3658.213403   1612.439680
# weight       -5505.211745  1290.695575  82368.423240  28555.758667
# acceleration     9.058930    -2.370842   -156.332976    -74.762382
# model_year      16.741163    -2.193499   -142.717137    -61.195866
#
#                      weight  acceleration  model_year
# mpg            -5505.211745      9.058930   16.741163
# cylinders       1290.695575     -2.370842   -2.193499
# displacement   82368.423240   -156.332976 -142.717137
# horsepower     28555.758667    -74.762382  -61.195866
# weight        717140.990526   -974.899011 -959.946344
# acceleration    -974.899011      7.604848    2.938105
# ...

# %%
mpg.corr()
#method = pearson spearman kendall
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.755776 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.823252  0.896017
# displacement -0.804203   0.950721      1.000000    0.873713  0.932824
# horsepower   -0.755776   0.823252      0.873713    1.000000  0.839749
# weight       -0.831741   0.896017      0.932824    0.839749  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.675144 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.412152 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.675144   -0.412152
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
sns.heatmap(mpg.corr(),annot=True, cbar=False);
## 다중공선성 ... 결국 Feature Selection

# %%
mpg.filter(regex='[^=weight]',axis=1).boxplot()
## 아웃라이어 처리도 이슈일 것! proud detection
## PyOD 라이브러리 딥러닝으로 아웃라이어 디텍팅

# %% [markdown]
# 아웃라이어의 경우 없앨까?? 살릴까?? 를 모델을 통해서 결정!
#
# 박스플랏을 통해서 또한 Normalization을 할지 말지도 캐치할 수 있다!!

# %%
mpg.describe([.005,.5,.75])
##퍼센트를 줘서 이 퍼센트가 어느정도인가를 알 수 있다.
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  102.939698  2970.424623
# std      7.815984    1.701004    104.269838   40.155195   846.841774
# min      9.000000    3.000000     68.000000    3.000000  1613.000000
# 0.5%    10.000000    3.000000     70.000000    3.000000  1753.410000
# 50%     23.000000    4.000000    148.500000   92.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 0.5%       8.500000   70.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
pew = pd.read_csv("pew.txt",sep='\t')

# %%
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %% [markdown]
# 데이터가 구데기다!!!! 왜냐하면 구간으로 주게 되면 특정 값이 필요하게 되면 데이터를 다시 해야한다
#
# 이런 포맷을 **wide format** 사람이 보기용!

# %%
pew.melt(id_vars=['religion'], var_name = '문', value_name='근영') ##rename을 통해서 해도 된다
# Out:
#                     religion                   문    근영
# 0                   Agnostic               <$10k    27
# 1                    Atheist               <$10k    12
# 2                   Buddhist               <$10k    27
# 3                   Catholic               <$10k   418
# 4         Don’t know/refused               <$10k    15
# 5           Evangelical Prot               <$10k   575
# 6                      Hindu               <$10k     1
# 7    Historically Black Prot               <$10k   228
# 8          Jehovah's Witness               <$10k    20
# 9                     Jewish               <$10k    19
# 10             Mainline Prot               <$10k   289
# 11                    Mormon               <$10k    29
# 12                    Muslim               <$10k     6
# 13                  Orthodox               <$10k    13
# 14           Other Christian               <$10k     9
# 15              Other Faiths               <$10k    20
# ...

# %% [markdown]
# 이런 포맷을 **long format**(분석용!) 첫번째 인자에는 구분자, 두번째부터는 변수 값

# %%
pew = pew.melt(id_vars=['religion'])

# %%
pew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
# religion    180 non-null object
# variable    180 non-null object
# value       180 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 4.3+ KB

# %% [markdown]
# groupby, describe를 통해서 의미 있는 값을 묶어서 해야한다.

# %%
pew.groupby('variable').mean()
# Out:
#                          value
# variable
# $10-20k             154.500000
# $100-150k           177.611111
# $20-30k             186.500000
# $30-40k             183.444444
# $40-50k             171.388889
# $50-75k             288.055556
# $75-100k            221.666667
# <$10k               107.222222
# >150k               144.888889
# Don't know/refused  340.055556

# %% [markdown]
# 데이터를 받았는데 tidy data가 아니라면 tidy data로 바꾸고 나서 시작을 해야할 것!!

# %%
weather = pd.read_csv("weather.txt",sep='\t')

# %%
weather
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %% [markdown]
# 일단 이 데이터도 보자마자 melt 해야할 것!! 분석하기 구데기다...

# %%
weather.melt(weather.columns[:4],var_name='day').dropna()
# Out:
#               id  year  month element  day  value
# 20   MX000017004  2010     12    TMAX   d1  299.0
# 21   MX000017004  2010     12    TMIN   d1  138.0
# 24   MX000017004  2010      2    TMAX   d2  273.0
# 25   MX000017004  2010      2    TMIN   d2  144.0
# 40   MX000017004  2010     11    TMAX   d2  313.0
# 41   MX000017004  2010     11    TMIN   d2  163.0
# 46   MX000017004  2010      2    TMAX   d3  241.0
# 47   MX000017004  2010      2    TMIN   d3  144.0
# 56   MX000017004  2010      7    TMAX   d3  286.0
# 57   MX000017004  2010      7    TMIN   d3  175.0
# 84   MX000017004  2010     11    TMAX   d4  272.0
# 85   MX000017004  2010     11    TMIN   d4  120.0
# 92   MX000017004  2010      3    TMAX   d5  321.0
# 93   MX000017004  2010      3    TMIN   d5  142.0
# 102  MX000017004  2010      8    TMAX   d5  296.0
# 103  MX000017004  2010      8    TMIN   d5  158.0
# 104  MX000017004  2010     10    TMAX   d5  270.0
# 105  MX000017004  2010     10    TMIN   d5  140.0
# ...

# %%
weather = weather.melt(weather.columns[:4],var_name='day').dropna()

# %%
weather.describe()
##year는 싹 다 2010
# Out:
#          year      month       value
# count    66.0  66.000000   66.000000
# mean   2010.0   7.212121  219.212121
# std       0.0   3.417220   77.294744
# min    2010.0   1.000000   79.000000
# 25%    2010.0   4.000000  150.000000
# 50%    2010.0   8.000000  211.500000
# 75%    2010.0  10.000000  289.250000
# max    2010.0  12.000000  363.000000

# %%
weather.drop(columns=['id','year'],inplace=True)

# %%
weather.head() ##인덱스 맘에 안듬!!
# Out:
#     month element day  value
# 20     12    TMAX  d1  299.0
# 21     12    TMIN  d1  138.0
# 24      2    TMAX  d2  273.0
# 25      2    TMIN  d2  144.0
# 40     11    TMAX  d2  313.0

# %%
weather.reset_index(drop=True, inplace=True)

# %%
weather.head() ##숫자만 뽑아내는 아이들로 하고 싶다!!
# Out:
#    month element day  value
# 0     12    TMAX  d1  299.0
# 1     12    TMIN  d1  138.0
# 2      2    TMAX  d2  273.0
# 3      2    TMIN  d2  144.0
# 4     11    TMAX  d2  313.0

# %%
weather.day = weather.day.str.replace('d',"")

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 4 columns):
# month      66 non-null int64
# element    66 non-null object
# day        66 non-null object
# value      66 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
weather.day = weather.day.astype("int64")

# %%
weather.sort_values('month').head()
##정렬했더니 또 인덱스가 문제
# Out:
#     month element  day  value
# 63      1    TMIN   30  145.0
# 62      1    TMAX   30  278.0
# 43      2    TMIN   23  107.0
# 2       2    TMAX    2  273.0
# 3       2    TMIN    2  144.0

# %%
weather = weather.sort_values('month')

# %%
weather.reset_index(drop=True, inplace=True)

# %%
weather.head()
# Out:
#    month element  day  value
# 0      1    TMIN   30  145.0
# 1      1    TMAX   30  278.0
# 2      2    TMIN   23  107.0
# 3      2    TMAX    2  273.0
# 4      2    TMIN    2  144.0

# %%
weather = pd.read_csv("weather.txt",sep='\t')

# %%
pd.wide_to_long(weather,'d',['id','year','month','element'],'').dropna()
##d1 d2에 따른 값, 그리고 멀티인덱스를 공통적인 걸 그룹화! ... 조금 더 보기가 편하다~ melt보다는 조금 더 편하다!!
# Out:
#                                        d
# id          year month element
# MX000017004 2010 1     TMAX    30  278.0
#                        TMIN    30  145.0
#                  2     TMAX    2   273.0
#                                3   241.0
#                                11  297.0
#                                23  299.0
#                        TMIN    2   144.0
#                                3   144.0
#                                11  134.0
#                                23  107.0
#                  3     TMAX    5   321.0
#                                10  345.0
#                                16  311.0
#                        TMIN    5   142.0
#                                10  168.0
#                                16  176.0
#                  4     TMAX    27  363.0
#                        TMIN    27  167.0
#                  5     TMAX    27  332.0
#                        TMIN    27  182.0
#                  6     TMAX    17  280.0
# ...

# %% [markdown]
# 판다스에서 melt를 쓰는 방식 2가지!!

# %%
billboard = pd.read_csv("billboard.csv",parse_dates=True,date_parser=True)
##옵션에서 주더라도, 안바뀔 수가 있다...

# %%
billboard.head()
##보자마자 wide data를 long data로 바꿔야 한다.
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %% [markdown]
# 이 아이는 7개를 고정 시키고 나머지를 싹다 정리!! year는 모두 2000일 것!! 그럼 날리자!
#
# week 고치고, 데이터타입 고치고, 이름 고치고!! 이렇게 하는 것들이 tidy data!!
#
# 우리가 본 데이터들은 예쁜 데이터만을 보았을 것!! 그런데 실 데이터들은 예쁘지 않다!!

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
# year               317 non-null int64
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null object
# date.peaked        317 non-null object
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...

# %%
pd.wide_to_long(billboard)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-64bc16efec75> in <module>()
# ----> 1 pd.wide_to_long(billboard)
#
# TypeError: wide_to_long() missing 3 required positional arguments: 'stubnames', 'i', and 'j'
