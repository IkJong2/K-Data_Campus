# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'dark_background',
#  'seaborn-poster',
#  'classic',
#  'seaborn-talk',
#  'seaborn-colorblind',
#  'seaborn-bright',
#  'seaborn-whitegrid',
#  'seaborn-deep',
#  'seaborn-white',
#  'fivethirtyeight',
#  'seaborn-darkgrid',
#  'seaborn-notebook',
#  'seaborn',
#  'seaborn-pastel',
#  'grayscale',
#  '_classic_test',
#  'seaborn-muted',
#  'bmh',
#  'ggplot',
#  'seaborn-ticks',
#  'seaborn-dark-palette',
#  'seaborn-paper']

# %%
plt.style.use("ggplot")

# %%
data = pd.read_excel("store.xlsx", encoding="CP-949")

# %%
data
# Out:
#           광역시도   시군구     업종대분류         업종중분류   1년미만   1~2년   2~3년   3~5년  \
# 0        서울특별시   종로구  관광/여가/오락      연극/영화/극장    1.0    2.0   42.0   39.0
# 1        서울특별시   종로구  관광/여가/오락         전시/관람    0.0    6.0   18.0   35.0
# 2        서울특별시   종로구  관광/여가/오락  PC/오락/당구/볼링등    0.0    5.0   12.0   86.0
# 3        서울특별시   종로구  관광/여가/오락    경마/경륜/성인오락    0.0    1.0    1.0    1.0
# 4        서울특별시   종로구  관광/여가/오락        스포츠/운동    0.0    0.0    1.0    0.0
# 5        서울특별시   종로구  관광/여가/오락     요가/단전/마사지    0.0    1.0    6.0   18.0
# 6        서울특별시   종로구  관광/여가/오락      놀이/여가/취미    0.0    0.0    4.0    6.0
# 7        서울특별시   종로구  관광/여가/오락      무도/유흥/가무    1.0    7.0   10.0   75.0
# 8        서울특별시   종로구       부동산         부동산중개   33.0   20.0   47.0   60.0
# 9        서울특별시   종로구       부동산      평가/개발/관리    2.0    3.0   11.0    3.0
# 10       서울특별시   종로구       부동산      부동산관련서비스    0.0    0.0    0.0    1.0
# 11       서울특별시   종로구       부동산         부동산임대    1.0    1.0   25.0   18.0
# ...

# %%
data_raw = data.copy()

# %%
import missingno as mino

# %%
mino.matrix(data);

# %%
data_raw.isna().all()
# Out:
# 광역시도     False
# 시군구      False
# 업종대분류    False
# 업종중분류    False
# 1년미만     False
# 1~2년     False
# 2~3년     False
# 3~5년     False
# 5년 이상    False
# dtype: bool

# %%
data_raw.isna().any()
# Out:
# 광역시도     False
# 시군구      False
# 업종대분류    False
# 업종중분류    False
# 1년미만      True
# 1~2년      True
# 2~3년      True
# 3~5년      True
# 5년 이상     True
# dtype: bool

# %%
data_raw_na = data_raw.dropna()

# %%
data = data_raw_na.melt(data_raw_na.columns[:4], var_name="년", value_name="수")

# %%
data.head()
# Out:
#     광역시도  시군구     업종대분류         업종중분류     년    수
# 0  서울특별시  종로구  관광/여가/오락      연극/영화/극장  1년미만  1.0
# 1  서울특별시  종로구  관광/여가/오락         전시/관람  1년미만  0.0
# 2  서울특별시  종로구  관광/여가/오락  PC/오락/당구/볼링등  1년미만  0.0
# 3  서울특별시  종로구  관광/여가/오락    경마/경륜/성인오락  1년미만  0.0
# 4  서울특별시  종로구  관광/여가/오락        스포츠/운동  1년미만  0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103085 entries, 0 to 103084
# Data columns (total 6 columns):
# 광역시도     103085 non-null object
# 시군구      103085 non-null object
# 업종대분류    103085 non-null object
# 업종중분류    103085 non-null object
# 년        103085 non-null object
# 수        103085 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 4.7+ MB

# %%
data['수'] = data["수"].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103085 entries, 0 to 103084
# Data columns (total 6 columns):
# 광역시도     103085 non-null object
# 시군구      103085 non-null object
# 업종대분류    103085 non-null object
# 업종중분류    103085 non-null object
# 년        103085 non-null object
# 수        103085 non-null int32
# dtypes: int32(1), object(5)
# memory usage: 4.3+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103085 entries, 0 to 103084
# Data columns (total 6 columns):
# 광역시도     103085 non-null object
# 시군구      103085 non-null object
# 업종대분류    103085 non-null object
# 업종중분류    103085 non-null object
# 년        103085 non-null object
# 수        103085 non-null int32
# dtypes: int32(1), object(5)
# memory usage: 4.3+ MB

# %%
data = data[data['수']!=0]

# %%
data.head()
# Out:
#      광역시도  시군구     업종대분류     업종중분류     년   수
# 0   서울특별시  종로구  관광/여가/오락  연극/영화/극장  1년미만   1
# 7   서울특별시  종로구  관광/여가/오락  무도/유흥/가무  1년미만   1
# 8   서울특별시  종로구       부동산     부동산중개  1년미만  33
# 9   서울특별시  종로구       부동산  평가/개발/관리  1년미만   2
# 11  서울특별시  종로구       부동산     부동산임대  1년미만   1

# %%
data.groupby("광역시도").count()
##이건 별로...
# Out:
#            시군구  업종대분류  업종중분류      년      수
# 광역시도
# 강원도       5691   5691   5691   5691   5691
# 경기도      12257  12257  12257  12257  12257
# 경상남도      5605   5605   5605   5605   5605
# 경상북도      6664   6664   6664   6664   6664
# 광주광역시     2058   2058   2058   2058   2058
# 대구광역시     3112   3112   3112   3112   3112
# 대전광역시     2040   2040   2040   2040   2040
# 부산광역시     5754   5754   5754   5754   5754
# 서울특별시     9933   9933   9933   9933   9933
# 세종특별자치시    401    401    401    401    401
# 울산광역시     1798   1798   1798   1798   1798
# 인천광역시     3586   3586   3586   3586   3586
# 전라남도      6500   6500   6500   6500   6500
# 전라북도      4397   4397   4397   4397   4397
# 제주특별자치도    806    806    806    806    806
# 충청남도      4969   4969   4969   4969   4969
# 충청북도      3543   3543   3543   3543   3543

# %%
##시 별로 업종중분류에서 연극/영화/극장이 얼마나 있는지
data[data.iloc[:,-3]  == '연극/영화/극장'].groupby('광역시도').count()
# Out:
#          시군구  업종대분류  업종중분류    년    수
# 광역시도
# 강원도       34     34     34   34   34
# 경기도      109    109    109  109  109
# 경상남도      41     41     41   41   41
# 경상북도      40     40     40   40   40
# 광주광역시     18     18     18   18   18
# 대구광역시     27     27     27   27   27
# 대전광역시     17     17     17   17   17
# 부산광역시     42     42     42   42   42
# 서울특별시     91     91     91   91   91
# 세종특별자치시    3      3      3    3    3
# 울산광역시     14     14     14   14   14
# 인천광역시     30     30     30   30   30
# 전라남도      35     35     35   35   35
# 전라북도      33     33     33   33   33
# 제주특별자치도    7      7      7    7    7
# 충청남도      40     40     40   40   40
# 충청북도      17     17     17   17   17

# %%
##서울시에 구별로 부동산 업이 몇개인지
data[(data.iloc[:,0] =="서울특별시")&(data.iloc[:,2]=="부동산")].groupby("시군구").count()
# Out:
#       광역시도  업종대분류  업종중분류   년   수
# 시군구
# 강남구     23     23     23  23  23
# 강동구     20     20     20  20  20
# 강북구     17     17     17  17  17
# 강서구     22     22     22  22  22
# 관악구     19     19     19  19  19
# 광진구     18     18     18  18  18
# 구로구     19     19     19  19  19
# 금천구     17     17     17  17  17
# 노원구     16     16     16  16  16
# 도봉구     17     17     17  17  17
# 동대문구    18     18     18  18  18
# 동작구     21     21     21  21  21
# 마포구     21     21     21  21  21
# 서대문구    18     18     18  18  18
# 서초구     21     21     21  21  21
# 성동구     18     18     18  18  18
# 성북구     17     17     17  17  17
# 송파구     22     22     22  22  22
# 양천구     18     18     18  18  18
# 영등포구    22     22     22  22  22
# 용산구     19     19     19  19  19
# 은평구     16     16     16  16  16
# 종로구     20     20     20  20  20
# 중구      21     21     21  21  21
# 중랑구     17     17     17  17  17

# %%
##서울시에 구별로 부동산 업이 몇개인지
data[(data.iloc[:,0] =="서울특별시")&(data.iloc[:,2]=="부동산")].groupby(("시군구","업종중분류")).count()
# Out:
# C:\Users\Ikjong\Anaconda3\envs\cuda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#                광역시도  업종대분류  년  수
# 시군구  업종중분류
# 강남구  부동산관련서비스     3      3  3  3
#      부동산임대        5      5  5  5
#      부동산중개        5      5  5  5
#      분양           5      5  5  5
#      평가/개발/관리     5      5  5  5
# 강동구  부동산관련서비스     4      4  4  4
#      부동산임대        5      5  5  5
#      부동산중개        5      5  5  5
#      분양           3      3  3  3
#      평가/개발/관리     3      3  3  3
# 강북구  부동산관련서비스     1      1  1  1
#      부동산임대        4      4  4  4
#      부동산중개        5      5  5  5
#      분양           3      3  3  3
#      평가/개발/관리     4      4  4  4
# 강서구  부동산관련서비스     3      3  3  3
#      부동산임대        4      4  4  4
#      부동산중개        5      5  5  5
#      분양           5      5  5  5
# ...

# %% [markdown]
# aggregate 분석은 통계에서만 관심을 가진다!! 인공지능분야에선 1도 관심가시지 않음!
#
# SAC(Split Apply Combine)기법 ... groupby의 숨은 기법!
#
# Split이 groupby!
#
# Apply가 count, sum, cumsum 등
#
# Combine은 그냥 Numpy에서 Reduction

# %%
t = data[(data.iloc[:,0] =="서울특별시")&(data.iloc[:,2]=="부동산")].groupby(("시군구","업종중분류"))
# Out:
# C:\Users\Ikjong\Anaconda3\envs\cuda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   """Entry point for launching an IPython kernel.

# %%
'__next__' in dir(t)
## 이터레이터는 아니다!!
## but! 이터러블(순회가능한 아이)이다. 그래서 for문에 사용가능
# Out:
# False

# %%
len(t)
# Out:
# 125

# %%
for i,j in t:
    print(i,j)
## i가 시군구 업종중분류, j가 나머지
## 왜 이걸 알려주냐?? 이런식으로 되~~~~게 많이 구현을 한다~~
# Out:
# ('강남구', '부동산관련서비스')         광역시도  시군구 업종대분류     업종중분류      년    수
# 43286  서울특별시  강남구   부동산  부동산관련서비스   2~3년    2
# 63903  서울특별시  강남구   부동산  부동산관련서비스   3~5년    6
# 84520  서울특별시  강남구   부동산  부동산관련서비스  5년 이상  110
# ('강남구', '부동산임대')         광역시도  시군구 업종대분류  업종중분류      년    수
# 2055   서울특별시  강남구   부동산  부동산임대   1년미만    6
# 22672  서울특별시  강남구   부동산  부동산임대   1~2년    5
# 43289  서울특별시  강남구   부동산  부동산임대   2~3년   68
# 63906  서울특별시  강남구   부동산  부동산임대   3~5년   79
# 84523  서울특별시  강남구   부동산  부동산임대  5년 이상  168
# ('강남구', '부동산중개')         광역시도  시군구 업종대분류  업종중분류      년    수
# 2053   서울특별시  강남구   부동산  부동산중개   1년미만   68
# 22670  서울특별시  강남구   부동산  부동산중개   1~2년   63
# 43287  서울특별시  강남구   부동산  부동산중개   2~3년  473
# 63904  서울특별시  강남구   부동산  부동산중개   3~5년  368
# 84521  서울특별시  강남구   부동산  부동산중개  5년 이상  702
# ('강남구', '분양')         광역시도  시군구 업종대분류 업종중분류      년    수
# 2054   서울특별시  강남구   부동산    분양   1년미만    1
# 22671  서울특별시  강남구   부동산    분양   1~2년    2
# 43288  서울특별시  강남구   부동산    분양   2~3년  207
# ...

# %%
from collections import Counter

# %%
Counter('aaaaaaaaaabbbbbbbbbbbc')
##반복되는 거 중에 몇개 있는지 알아내는 것
## 또 중요한게 Series에만 몇개 있는지 알아내는 것
# Out:
# Counter({'a': 10, 'b': 11, 'c': 1})

# %%
data["업종대분류"].value_counts()
##차이점은 이쁘게 만들었냐?
# Out:
# 소매          23597
# 생활서비스       15738
# 음식          14909
# 학문/교육       10891
# 관광/여가/오락     5323
# 부동산          3331
# 숙박           3095
# 스포츠          2230
# Name: 업종대분류, dtype: int64

# %%
Counter(data["업종대분류"])
##이 아이 또한 된다~
##딕셔너리 형태로 만들었는가?
# Out:
# Counter({'관광/여가/오락': 5323,
#          '부동산': 3331,
#          '생활서비스': 15738,
#          '소매': 23597,
#          '숙박': 3095,
#          '스포츠': 2230,
#          '음식': 14909,
#          '학문/교육': 10891})

# %%
x = Counter(data["업종대분류"])

# %%
t = x.most_common() ##리스트를 만들었다~
t
# Out:
# [('소매', 23597),
#  ('생활서비스', 15738),
#  ('음식', 14909),
#  ('학문/교육', 10891),
#  ('관광/여가/오락', 5323),
#  ('부동산', 3331),
#  ('숙박', 3095),
#  ('스포츠', 2230)]

# %%
t.sort()
t
# Out:
# [('관광/여가/오락', 5323),
#  ('부동산', 3331),
#  ('생활서비스', 15738),
#  ('소매', 23597),
#  ('숙박', 3095),
#  ('스포츠', 2230),
#  ('음식', 14909),
#  ('학문/교육', 10891)]

# %%
t.sort(key=lambda t:t[1])
t
# Out:
# [('스포츠', 2230),
#  ('숙박', 3095),
#  ('부동산', 3331),
#  ('관광/여가/오락', 5323),
#  ('학문/교육', 10891),
#  ('음식', 14909),
#  ('생활서비스', 15738),
#  ('소매', 23597)]

# %%
ss = data["업종대분류"]

# %%
ss.value_counts(True)
##이 아이는 sort를 내 멋대로 표현할 수 없다...
##하지만! normalize를 True로 하면 비율로 표현이 가능!!
# Out:
# 소매          0.298266
# 생활서비스       0.198928
# 음식          0.188450
# 학문/교육       0.137662
# 관광/여가/오락    0.067283
# 부동산         0.042104
# 숙박          0.039121
# 스포츠         0.028187
# Name: 업종대분류, dtype: float64

# %%
ss.value_counts(True).plot.pie();
# ss.value_counts(True).plot("pie")

# %%
ss.value_counts(True,False).plot.bar();

# %%
import numpy as np

# %%
t = data[(data['광역시도']=='서울특별시') & (data['업종대분류']=='부동산')].groupby(['시군구','업종중분류'])

# %%
t.agg(['count','sum',np.std]) 
#t.aggregate(['count','sum',np.std]) ##같은것!
##엑셀의 부분합 같은개념??
# Out:
#                   수
#               count   sum         std
# 시군구  업종중분류
# 강남구  부동산관련서비스     3   118   61.231800
#      부동산임대        5   326   66.885723
#      부동산중개        5  1674  273.904545
#      분양           5   351   85.963364
#      평가/개발/관리     5  1027  282.709745
# 강동구  부동산관련서비스     4    73   34.500000
#      부동산임대        5    37    7.231874
#      부동산중개        5   681  117.355017
#      분양           3     8    2.081666
#      평가/개발/관리     3    50   16.772994
# 강북구  부동산관련서비스     1    26         NaN
#      부동산임대        4    21    3.403430
#      부동산중개        5   121   24.263141
#      분양           3    11    3.785939
#      평가/개발/관리     4    47   19.551215
# 강서구  부동산관련서비스     3   144   80.541915
#      부동산임대        4    64   16.268579
#      부동산중개        5   528  100.231233
#      분양           5    28    5.727128
#      평가/개발/관리     5   127   50.147782
# 관악구  부동산관련서비스     3    66   35.510562
#      부동산임대        3    56   14.364308
#      부동산중개        5   546   84.662270
# ...

# %%
t.transform('count')
##groupby했던 것을 각각읳 형태로 보여주는 것!
# Out:
#        광역시도  업종대분류  년  수
# 8         5      5  5  5
# 9         5      5  5  5
# 11        5      5  5  5
# 103       5      5  5  5
# 105       5      5  5  5
# 106       5      5  5  5
# 198       5      5  5  5
# 200       4      4  4  4
# 201       5      5  5  5
# 290       5      5  5  5
# 291       5      5  5  5
# 294       4      4  4  4
# 383       5      5  5  5
# 385       4      4  4  4
# 477       5      5  5  5
# 479       5      5  5  5
# 569       5      5  5  5
# 572       5      5  5  5
# 665       5      5  5  5
# 754       5      5  5  5
# 844       5      5  5  5
# 845       5      5  5  5
# 936       5      5  5  5
# 1032      5      5  5  5
# 1118      5      5  5  5
# 1120      5      5  5  5
# 1212      5      5  5  5
# 1215      5      5  5  5
# 1307      5      5  5  5
# 1308      4      4  4  4
# ...     ...    ... .. ..
# 84241     3      3  3  3
# 84242     5      5  5  5
# 84243     3      3  3  3
# 84244     5      5  5  5
# 84245     5      5  5  5
# ...

# %%
t = data[(data['광역시도']=='서울특별시') | (data['광역시도']=='강원도') & (data['업종대분류']=='부동산')].groupby(['시군구','업종중분류'])

# %%
t.count()
# Out:
#                   광역시도  업종대분류  년  수
# 시군구 업종중분류
# 강남구 PC/오락/당구/볼링등     5      5  5  5
#     가구소매             5      5  5  5
#     가방/신발/액세서리       5      5  5  5
#     가전제품소매           5      5  5  5
#     가정/주방/인테리어       5      5  5  5
#     개인/가정용품수리        5      5  5  5
#     개인서비스            5      5  5  5
#     건강/미용식품          5      5  5  5
#     경마/경륜/성인오락       5      5  5  5
#     광고/인쇄            5      5  5  5
#     기타교육기관           4      4  4  4
#     기타서비스업           5      5  5  5
#     기타음식업            5      5  5  5
#     기타판매업            5      5  5  5
#     놀이/여가/취미         4      4  4  4
#     닭/오리요리           5      5  5  5
#     대중목욕탕/휴게         5      5  5  5
#     대행업              4      4  4  4
#     도서관/독서실          4      4  4  4
#     모텔/여관/여인숙        5      5  5  5
#     무도/유흥/가무         5      5  5  5
#     물품기기대여           5      5  5  5
#     민박/하숙            4      4  4  4
#     법무세무회계           5      5  5  5
#     별식/퓨전요리          5      5  5  5
# ...

# %% [markdown]
# 파이썬에서 or가 나오면 in 테크닉을 쓴다!
#
# in은 연산자이고, isin은 함수로 만들어 둔 것!
#
# 그래서 여러개의 조건이 있을 때, is in을 사용한다.
#
# is는 predicate 함수! 그래서 이 안에 이게 있나 없나를 보여줌!!

# %%
data['광역시도'].isin (['서울특별시','강원도'])
# Out:
# 0          True
# 7          True
# 8          True
# 9          True
# 11         True
# 13         True
# 14         True
# 15         True
# 18         True
# 19         True
# 21         True
# 22         True
# 24         True
# 26         True
# 28         True
# 29         True
# 30         True
# 31         True
# 32         True
# 33         True
# 35         True
# 37         True
# 38         True
# 39         True
# 40         True
# 41         True
# 42         True
# 43         True
# 45         True
# 46         True
#           ...
# 103054    False
# 103055    False
# 103056    False
# 103057    False
# 103058    False
# 103059    False
# 103060    False
# 103061    False
# 103062    False
# 103063    False
# 103064    False
# 103065    False
# 103066    False
# 103067    False
# 103068    False
# 103069    False
# 103070    False
# 103071    False
# 103072    False
# 103073    False
# 103074    False
# 103075    False
# 103076    False
# 103078    False
# ...

# %%
data.where(data['광역시도'].isin (['서울특별시','강원도'])).dropna()
##is in ... predicate와 where를 동시에 씀으로써 우리가 원하는 것만 가지고 올 수 있음!!
# Out:
#         광역시도  시군구     업종대분류          업종중분류      년      수
# 0      서울특별시  종로구  관광/여가/오락       연극/영화/극장   1년미만    1.0
# 7      서울특별시  종로구  관광/여가/오락       무도/유흥/가무   1년미만    1.0
# 8      서울특별시  종로구       부동산          부동산중개   1년미만   33.0
# 9      서울특별시  종로구       부동산       평가/개발/관리   1년미만    2.0
# 11     서울특별시  종로구       부동산          부동산임대   1년미만    1.0
# 13     서울특별시  종로구     생활서비스         기타서비스업   1년미만    3.0
# 14     서울특별시  종로구     생활서비스          광고/인쇄   1년미만    2.0
# 15     서울특별시  종로구     생활서비스     예식/의례/관혼상제   1년미만    3.0
# 18     서울특별시  종로구     생활서비스         법무세무회계   1년미만    5.0
# 19     서울특별시  종로구     생활서비스         행사/이벤트   1년미만    1.0
# 21     서울특별시  종로구     생활서비스           주택수리   1년미만    1.0
# 22     서울특별시  종로구     생활서비스             사진   1년미만    7.0
# 24     서울특별시  종로구     생활서비스       대중목욕탕/휴게   1년미만    5.0
# 26     서울특별시  종로구     생활서비스      개인/가정용품수리   1년미만    6.0
# 28     서울특별시  종로구     생활서비스          장례/묘지   1년미만    1.0
# ...

# %% [markdown]
# is 배웠던 것!
# 1. isna == isnull
# 2. isin
#
# 그리고 na가 아닌것 check
# - notna == notnull

# %%
data.notna()
# Out:
#         광역시도   시군구  업종대분류  업종중분류     년     수
# 0       True  True   True   True  True  True
# 7       True  True   True   True  True  True
# 8       True  True   True   True  True  True
# 9       True  True   True   True  True  True
# 11      True  True   True   True  True  True
# 13      True  True   True   True  True  True
# 14      True  True   True   True  True  True
# 15      True  True   True   True  True  True
# 18      True  True   True   True  True  True
# 19      True  True   True   True  True  True
# 21      True  True   True   True  True  True
# 22      True  True   True   True  True  True
# 24      True  True   True   True  True  True
# 26      True  True   True   True  True  True
# 28      True  True   True   True  True  True
# 29      True  True   True   True  True  True
# 30      True  True   True   True  True  True
# 31      True  True   True   True  True  True
# 32      True  True   True   True  True  True
# 33      True  True   True   True  True  True
# ...

# %%
pd.crosstab(data['광역시도'],data['년'])
# Out:
# 년        1~2년  1년미만  2~3년  3~5년  5년 이상
# 광역시도
# 강원도       779  1023  1082  1284   1523
# 경기도      2041  2229  2502  2687   2798
# 경상남도      821   898  1049  1307   1530
# 경상북도      876  1136  1260  1539   1853
# 광주광역시     363   383   418   439    455
# 대구광역시     509   574   632   686    711
# 대전광역시     330   365   437   451    457
# 부산광역시     873  1021  1128  1326   1406
# 서울특별시    1718  1728  2090  2158   2239
# 세종특별자치시    68    73    89    86     85
# 울산광역시     268   320   362   405    443
# 인천광역시     553   606   753   827    847
# 전라남도      847  1141  1236  1466   1810
# 전라북도      607   800   805  1019   1166
# 제주특별자치도   131   152   165   174    184
# 충청남도      684   887   943  1148   1307
# 충청북도      527   615   670   800    931

# %%
pd.crosstab(data['광역시도'],data['년'],data['수'],aggfunc="count")
# Out:
# 년        1~2년  1년미만  2~3년  3~5년  5년 이상
# 광역시도
# 강원도       779  1023  1082  1284   1523
# 경기도      2041  2229  2502  2687   2798
# 경상남도      821   898  1049  1307   1530
# 경상북도      876  1136  1260  1539   1853
# 광주광역시     363   383   418   439    455
# 대구광역시     509   574   632   686    711
# 대전광역시     330   365   437   451    457
# 부산광역시     873  1021  1128  1326   1406
# 서울특별시    1718  1728  2090  2158   2239
# 세종특별자치시    68    73    89    86     85
# 울산광역시     268   320   362   405    443
# 인천광역시     553   606   753   827    847
# 전라남도      847  1141  1236  1466   1810
# 전라북도      607   800   805  1019   1166
# 제주특별자치도   131   152   165   174    184
# 충청남도      684   887   943  1148   1307
# 충청북도      527   615   670   800    931

# %%
pd.crosstab(data['년'], data['광역시도'], data['수'], aggfunc="count")
# Out:
# 광역시도    강원도   경기도  경상남도  경상북도  광주광역시  대구광역시  대전광역시  부산광역시  서울특별시  세종특별자치시  \
# 년
# 1~2년    779  2041   821   876    363    509    330    873   1718       68
# 1년미만   1023  2229   898  1136    383    574    365   1021   1728       73
# 2~3년   1082  2502  1049  1260    418    632    437   1128   2090       89
# 3~5년   1284  2687  1307  1539    439    686    451   1326   2158       86
# 5년 이상  1523  2798  1530  1853    455    711    457   1406   2239       85
#
# 광역시도   울산광역시  인천광역시  전라남도  전라북도  제주특별자치도  충청남도  충청북도
# 년
# 1~2년     268    553   847   607      131   684   527
# 1년미만     320    606  1141   800      152   887   615
# 2~3년     362    753  1236   805      165   943   670
# 3~5년     405    827  1466  1019      174  1148   800
# 5년 이상    443    847  1810  1166      184  1307   931

# %%
data.groupby('년').count()
# Out:
#         광역시도    시군구  업종대분류  업종중분류      수
# 년
# 1~2년   11995  11995  11995  11995  11995
# 1년미만   13951  13951  13951  13951  13951
# 2~3년   15621  15621  15621  15621  15621
# 3~5년   17802  17802  17802  17802  17802
# 5년 이상  19745  19745  19745  19745  19745

# %%
data.groupby(['년','광역시도']).count().unstack()
# Out:
#         시군구                                                         ...   \
# 광역시도    강원도   경기도  경상남도  경상북도 광주광역시 대구광역시 대전광역시 부산광역시 서울특별시 세종특별자치시 ...
# 년                                                                   ...
# 1~2년    779  2041   821   876   363   509   330   873  1718      68 ...
# 1년미만   1023  2229   898  1136   383   574   365  1021  1728      73 ...
# 2~3년   1082  2502  1049  1260   418   632   437  1128  2090      89 ...
# 3~5년   1284  2687  1307  1539   439   686   451  1326  2158      86 ...
# 5년 이상  1523  2798  1530  1853   455   711   457  1406  2239      85 ...
#
#           수
# 광역시도  부산광역시 서울특별시 세종특별자치시 울산광역시 인천광역시  전라남도  전라북도 제주특별자치도  충청남도 충청북도
# 년
# 1~2년    873  1718      68   268   553   847   607     131   684  527
# 1년미만   1021  1728      73   320   606  1141   800     152   887  615
# 2~3년   1128  2090      89   362   753  1236   805     165   943  670
# 3~5년   1326  2158      86   405   827  1466  1019     174  1148  800
# ...

# %% [markdown]
# 이런식으로 하는게 어렵다!! 그래서 Crosstab이 나왔다~~ 그래서 그래프 그릴 때 되게 좋다!!

# %%
b = pd.crosstab(data['년'], data['광역시도'], data['수'], aggfunc="count")

# %%
pd.crosstab(data['년'], data['광역시도'], data['수'], aggfunc="count").plot.bar();

# %%
data.pivot_table("수","년", aggfunc='count', margins=True)
##부분합도 가능!! aggfunc는 default가 mean
# Out:
#            수
# 년
# 1~2년   11995
# 1년미만   13951
# 2~3년   15621
# 3~5년   17802
# 5년 이상  19745
# All    79114

# %% [markdown]
# Groupby 삼총사
# 1. groupby
# 2. croostab
# 3. pivot_table
#
# 요론 놈들이 결국 분석을 할 때, 기초 통계치를 보여줄 때 필요할 것!!

# %%
import pdvega

# %% [markdown]
# ### Grammer of graphics
# - 그래프를 그리는 데 있어 필요한 문법!!
# - ggplot은 프로그래밍
# - pdvega 는 웹서비스!

# %%
b.vgplot.bar()
## 이 기법!! 몽키패치
## D3가 어려워서 나온 것이 vegalite
# Out:
# <div class="vega-embed" id="0ae8e072-5b05-4c47-b702-0840ec545497"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %% [markdown]
# R을 쓰는 이유??
#
# 새로운 통계기법을 바로바로 써먹을 수 있다!
#
# 그래서 이걸로 밥 벌어 먹으려면 새로운 기술에 민감해야 한다!!
#
# 밥 벌어먹고 부자되려면 파이썬을 해야한다!
