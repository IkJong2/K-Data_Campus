# %%
import base64
from io import BytesIO

# %%
import folium
m = folium.Map(location=[37.5665, 126.9780])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
icon_url = 'https://ap.imagensbrasil.org/images/2019/07/30/jongik.png'

# %%
icon = folium.features.CustomIcon(icon_url, icon_size=(45, 45)) ##이거 무조건 url이여야 함 by stackoverflow

# %%
icon

# %%
m3 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain')

folium.Marker([37.5248, 126.9375], popup='<i>Mt. Hood Meadows</i>', 
icon=folium.Icon(icon='cloud')).add_to(m3)
folium.CircleMarker([37.5311, 126.9113], popup='<b>Timberline Lodge</b>').add_to(m3)

# %%
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m3 = folium.Map(location=[35.8534, 128.5986], tiles='Stamen Terrain')

icon = folium.features.CustomIcon(icon_url, icon_size=(45, 45)) ##이거 무조건 url이여야 함 by stackoverflow
folium.Marker([35.8048, 128.6075], popup='<i>존넨쉬름</i>', icon=icon).add_to(m3)

m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m4 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
folium.Circle(radius=100, 
location= [37.5248, 126.9375],
popup='The Waterfront', 
color='crimson', 
fill=False, 
).add_to(m4)

##링크가 써클에서만 링크가 걸린다

# folium.CircleMarker(
# location=[37.5311, 126.9113], 
# radius=50, 
# popup='Laurelhurst Park', 
# color='#3186cc', 
# fill=True, 
# fill_color='#3186cc' 
# ).add_to(m4)
#m4

# %%
m4 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
# folium.Circle(radius=100, 
# location= [37.5248, 126.9375],
# popup='The Waterfront', 
# color='crimson', 
# fill=False, 
# ).add_to(m4)

folium.CircleMarker(
location=[37.5311, 126.9113], 
radius=50, 
popup='Laurelhurst Park', 
color='#3186cc', 
fill=True, 
fill_color='#3186cc' 
).add_to(m4)
m4

## 써클 전체가 링크가 걸림
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m5 = folium.Map(location=[37.5665, 126.9780], tiles='Stamen Toner')
m5.add_child(folium.LatLngPopup())
## 위도 경도 알려주는 아이!!
## 분석기법X 그냥 정보제공~
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m6 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 
m6.add_child(folium.ClickForMarker(popup="ClickPoint"))
##이 뒤에 함수를 하여서 바로바로 실행되게끔 하는 것!
##이것들은 Just 분석용이다~~
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m7 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    popup='polygon1',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=5
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    popup='polygon2',
    fill_color='#45647d',
    number_of_sides=4,
    radius=10
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    popup='polygon3',
    fill_color='#769d96',
    number_of_sides=6,
    radius=15
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    popup='polygon4',
    fill_color='#769d98',
    number_of_sides=8,
    radius=20
    ).add_to(m7)
m7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import random

#Iterable
list_data = [10, 20, 30, 20, 15, 30, 45]

#Dicts of iterables
cat_1 = ['y1', 'y2', 'y3', 'y4']
index_1 = range(0, 21, 1)
multi_iter1 = {'index': index_1}
for cat in cat_1:
    multi_iter1[cat] = [random.randint(10, 100) for x in index_1]

cat_2 = ['y' + str(x) for x in range(0, 10, 1)]
index_2 = range(1, 21, 1)
multi_iter2 = {'index': index_2}
for cat in cat_2:
    multi_iter2[cat] = [random.randint(10, 100) for x in index_2]

# %%
# !pip install vincent
# Out:
# Collecting vincent
#   Downloading https://files.pythonhosted.org/packages/11/bf/a12ecaa21a2e376a16de67e09f64a38a4acd95e04e5dc35ad2f13a6f0bfd/vincent-0.4.4.tar.gz
# Requirement already satisfied: pandas in c:\users\ikjong\anaconda3\envs\cuda\lib\site-packages (from vincent) (0.23.4)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\ikjong\anaconda3\envs\cuda\lib\site-packages (from pandas->vincent) (1.16.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\ikjong\anaconda3\envs\cuda\lib\site-packages (from pandas->vincent) (2.7.3)
# Requirement already satisfied: pytz>=2011k in c:\users\ikjong\anaconda3\envs\cuda\lib\site-packages (from pandas->vincent) (2019.1)
# Requirement already satisfied: six>=1.5 in c:\users\ikjong\anaconda3\envs\cuda\lib\site-packages (from python-dateutil>=2.5.0->pandas->vincent) (1.12.0)
# Building wheels for collected packages: vincent
#   Building wheel for vincent (setup.py): started
#   Building wheel for vincent (setup.py): finished with status 'done'
#   Created wheel for vincent: filename=vincent-0.4.4-cp35-none-any.whl size=35175 sha256=1386553b9d40ccdc25b2cd7d82f28fcc85479c36617d30f2c4bcf029955dfdde
#   Stored in directory: C:\Users\Ikjong\AppData\Local\pip\Cache\wheels\4c\0d\8a\65f34c765c6094a71cce3e42a49a26533eef61695e9b505f03
# Successfully built vincent
# Installing collected packages: vincent
# Successfully installed vincent-0.4.4

# %%
import vincent
bar = vincent.Bar(multi_iter1['y1'])
bar.axis_titles(x='Index', y='Value')
bar.to_json('asset/vis1.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-8f5418f7cb03> in <module>()
#       2 bar = vincent.Bar(multi_iter1['y1'])
#       3 bar.axis_titles(x='Index', y='Value')
# ----> 4 bar.to_json('asset/vis1.json')
#
# ~\Anaconda3\envs\cuda\lib\site-packages\vincent\core.py in to_json(self, path, html_out, html_path, validate, pretty_print)
#     357
#     358         if path:
# --> 359             with open(path, 'w') as f:
#     360                 json.dump(self.grammar, f, default=encoder, sort_keys=True,
#     361                           **dumps_args)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'asset/vis1.json'

# %%
line = vincent.Line(multi_iter1, iter_idx='index')
line.axis_titles(x='Index', y='Value')
line.legend(title='Categories')
line.to_json('asset/vis2.json')

# %%
scatter = vincent.Scatter(multi_iter2, iter_idx='index')
scatter.axis_titles(x='Index', y='Data Value')
scatter.legend(title='Categories')
scatter.colors(brew='Set3')
scatter.to_json('asset/vis3.json')

# %%
area = vincent.Area(list_data)
area.to_json('asset/vis4.json')

# %%
import json
m8 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    fill_color='#132b5e',
    radius=5,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis1.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    fill_color='#45647d',
    radius=10,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis2.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    fill_color='#769d96',
    radius=15,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis3.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    fill_color='#769d96',
    radius=20,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis4.json')), width=450, height=250))
    ).add_to(m8)
m8
##노가다해서 해야함....
##하지만 지도를 누르면 어떤 것들이 나오게끔 해주면 사람들은 좋아함!!
##그래서 대회용으로 괜찮음~~
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_topo_json = open('asset/seoul_municipalities_topo_simple.json', encoding='utf8')
seoul_topo_json = json.load(seoul_topo_json)

seoul_geo_json = open('asset/seoul_municipalities_geo_simple.json',encoding='utf-8')
seoul_geo_json = json.load(seoul_geo_json)

# %%
m9 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

folium.GeoJson(seoul_geo_json,name='geojson').add_to(m9)

folium.TopoJson(seoul_topo_json,"objects.seoul_municipalities_geo",name='topojson').add_to(m9)

folium.LayerControl().add_to(m9)
m9
##하는 이유가 히트맵을 이용하기 위해~
##경계면 만드는 것 -> 예전에 50만원씩 받았드아...
##이게 썩 중요한 것은 아니다... 지도 히트맵을 찍는 것이 중요!!
##이 안에 있는 내용이 판다스 데이터 프레임을 가지고 가능!!
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']
# Out:
# [{'arcs': [[0, 1, 2]],
#   'type': 'Polygon',
#   'properties': {'code': '11250',
#    'name': '강동구',
#    'name_eng': 'Gangdong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[3, -2, 4, 5]],
#   'type': 'Polygon',
#   'properties': {'code': '11240',
#    'name': '송파구',
#    'name_eng': 'Songpa-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[6, -6, 7, 8, 9, 10]],
#   'type': 'Polygon',
#   'properties': {'code': '11230',
#    'name': '강남구',
#    'name_eng': 'Gangnam-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-9, 11, 12, 13, 14]],
#   'type': 'Polygon',
#   'properties': {'code': '11220',
#    'name': '서초구',
#    'name_eng': 'Seocho-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-13, 15, 16, 17, 18]],
#   'type': 'Polygon',
#   'properties': {'code': '11210',
#    'name': '관악구',
#    'name_eng': 'Gwanak-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-14, -19, 19, 20]],
#   'type': 'Polygon',
#   'properties': {'code': '11200',
#    'name': '동작구',
#    'name_eng': 'Dongjak-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[21, 22, -20, 23, 24, 25]],
#   'type': 'Polygon',
#   'properties': {'code': '11190',
#    'name': '영등포구',
#    'name_eng': 'Yeongdeungpo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-17, 26, 27]],
#   'type': 'Polygon',
#   'properties': {'code': '11180',
#    'name': '금천구',
#    'name_eng': 'Geumcheon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[28, -24, -18, -28, 29]],
#   'type': 'Polygon',
#   'properties': {'code': '11170',
#    'name': '구로구',
#    'name_eng': 'Guro-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[30, -26, 31, 32]],
#   'type': 'Polygon',
#   'properties': {'code': '11160',
#    'name': '강서구',
#    'name_eng': 'Gangseo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-32, -25, -29, 33]],
#   'type': 'Polygon',
#   'properties': {'code': '11150',
#    'name': '양천구',
#    'name_eng': 'Yangcheon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[34, 35, 36, -22, -31, 37, 38]],
#   'type': 'Polygon',
#   'properties': {'code': '11140',
#    'name': '마포구',
#    'name_eng': 'Mapo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[39, 40, -35, 41]],
#   'type': 'Polygon',
#   'properties': {'code': '11130',
#    'name': '서대문구',
#    'name_eng': 'Seodaemun-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[42, -42, -39, 43]],
#   'type': 'Polygon',
#   'properties': {'code': '11120',
#    'name': '은평구',
#    'name_eng': 'Eunpyeong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[44, 45, 46, 47, 48]],
#   'type': 'Polygon',
#   'properties': {'code': '11110',
#    'name': '노원구',
#    'name_eng': 'Nowon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-48, 49, 50]],
#   'type': 'Polygon',
#   'properties': {'code': '11100',
#    'name': '도봉구',
#    'name_eng': 'Dobong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-50, -47, 51, 52]],
#   'type': 'Polygon',
#   'properties': {'code': '11090',
#    'name': '강북구',
#    'name_eng': 'Gangbuk-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[53, -52, -46, 54, 55, 56]],
#   'type': 'Polygon',
#   'properties': {'code': '11080',
#    'name': '성북구',
#    'name_eng': 'Seongbuk-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-45, 57, 58, 59, -55]],
#   'type': 'Polygon',
#   'properties': {'code': '11070',
#    'name': '중랑구',
#    'name_eng': 'Jungnang-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-56, -60, 60, 61, 62]],
#   'type': 'Polygon',
#   'properties': {'code': '11060',
#    'name': '동대문구',
#    'name_eng': 'Dongdaemun-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-59, 63, -3, -4, -7, 64, -61]],
#   'type': 'Polygon',
#   'properties': {'code': '11050',
#    'name': '광진구',
#    'name_eng': 'Gwangjin-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-62, -65, -11, 65, 66]],
#   'type': 'Polygon',
#   'properties': {'code': '11040',
#    'name': '성동구',
#    'name_eng': 'Seongdong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-66, -10, -15, -21, -23, -37, 67]],
#   'type': 'Polygon',
#   'properties': {'code': '11030',
#    'name': '용산구',
#    'name_eng': 'Yongsan-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-67, -68, -36, -41, 68]],
#   'type': 'Polygon',
#   'properties': {'code': '11020',
#    'name': '중구',
#    'name_eng': 'Jung-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[69, -57, -63, -69, -40, -43]],
#   'type': 'Polygon',
#   'properties': {'code': '11010',
#    'name': '종로구',
#    'name_eng': 'Jongno-gu',
#    'base_year': '2013',
#    'style': {}}}]

# %%
data = pd.DataFrame.from_dict(seoul_geo_json['features']).properties
# data = pd.DataFrame.from_dict(seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']).properties

# %%
keys = data[0].keys()

# %%
for i in keys:
    print(i)
# Out:
# name
# name_eng
# base_year
# code

# %%
data_list = {}
for key in keys:
    temp_list = []
    for inst in data:
        temp_list.append(inst[key])
    data_list[key] = temp_list

# %%
data_list.keys()
# Out:
# dict_keys(['name', 'name_eng', 'base_year', 'code'])

# %%
seoul_df = pd.DataFrame.from_dict(data_list)

# %%
seoul_df.head()
# Out:
#   base_year   code name     name_eng
# 0      2013  11250  강동구  Gangdong-gu
# 1      2013  11240  송파구    Songpa-gu
# 2      2013  11230  강남구   Gangnam-gu
# 3      2013  11220  서초구    Seocho-gu
# 4      2013  11210  관악구    Gwanak-gu

# %%
t = seoul_df.apply()

# %%
seoul_df.to_csv('seoul_geo_df.csv')

# %%
m10 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

seoul_geo_df = pd.read_csv('asset/seoul_geo_df.csv')
m10.choropleth(
    geo_data=seoul_geo_json,
    name='choropleth',
    data=seoul_geo_df,
    columns=['name', 'code'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Seoul_choropleth'
)
# Out:
# C:\Users\Ikjong\Anaconda3\envs\cuda\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %% [markdown]
# choropleth!!
#
# 아직까지 마커 찍는거는 안됨....

# %%
m10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
